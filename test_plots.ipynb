# %%
# %matplotlib notebook
from matplotlib import pyplot
pyplot.plot([1, 2, 3, 4, 2])
pyplot.ylabel('some numbers')
pyplot.show()
# Out:
# <img src="data:image/png;base64,..." width="469">

# %%
# %matplotlib inline
from matplotlib import pyplot
pyplot.plot([1, 2, 3, 4, 2])
pyplot.ylabel('some numbers')
pyplot.show()

# %%
from matplotlib import pyplot
pyplot.plot([1, 2, 3, 4, 2])
pyplot.ylabel('some numbers')
pyplot.show()
